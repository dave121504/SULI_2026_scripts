# %%
import act

## INSERT NAME OF DATASTREAM AND RENAME THE OUTPUT FOLDER 

files = act.discovery.download_arm_data(
    username="dcouch",
    token="64a0e61c0a0013e7",
    datastream="bnfstamppcpS14.b1",
    startdate="2025-06-04",
    enddate="2026-06-04",
    output="/Users/dave121504/Downloads/ARM_BNF_STAMP_data/S14_precip"
)
# Out:
# [DOWNLOADING] bnfstamppcpS14.b1.20250604.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250605.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250606.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250607.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250608.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250609.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250610.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250611.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250612.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250613.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250614.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250615.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250616.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250617.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250618.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250619.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250620.000000.nc
# [DOWNLOADING] bnfstamppcpS14.b1.20250621.000000.nc
# ...

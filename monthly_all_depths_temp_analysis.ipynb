# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from datetime import timedelta
from netCDF4 import Dataset, date2num, num2date
import cftime
import glob
import os
import csv
# %matplotlib inline
import datetime
import matplotlib.dates as mdates
import matplotlib.dates as md
import metpy.calc as mpcalc
from metpy.units import units
import matplotlib.gridspec as gridspec
from matplotlib.ticker import MaxNLocator

files_swats = sorted(glob.glob('/Users/dave121504/ARM Project/SWATS Files/sgpswats*.nc'))
swats = xr.open_mfdataset(files_swats, combine='by_coords')

files_stamp = sorted(glob.glob('/Users/dave121504/ARM Project/STAMP Files/sgpstamp*.nc'))
stamp = xr.open_mfdataset(files_stamp, combine='by_coords')

# %%
fig, axes = plt.subplots(2, 2, figsize = (20, 12))

time_swats = swats['time']
time_stamp = stamp['time']

######   EAST  ######
#5cm, STARTING WITH SWATS (plot A)
swats_tempE_5 = swats['tsoil_e'].isel(depth=0)
swats_monthly_temp_E_5 = swats_tempE_5.resample(time='1ME').mean()

#15cm
swats_tempE_15 = swats['tsoil_e'].isel(depth=1)
swats_monthly_temp_E_15 = swats_tempE_15.resample(time='1ME').mean()

#25cm
swats_tempE_25 = swats['tsoil_e'].isel(depth=2)
swats_monthly_temp_E_25 = swats_tempE_25.resample(time='1ME').mean()


#35cm
swats_tempE_35 = swats['tsoil_e'].isel(depth=3)
swats_monthly_temp_E_35 = swats_tempE_35.resample(time='1ME').mean()

#60cm
swats_tempE_60 = swats['tsoil_e'].isel(depth=4)
swats_monthly_temp_E_60 = swats_tempE_60.resample(time='1ME').mean()

#swats temps plot (a)
axes[0,0].plot(swats_monthly_temp_E_5['time'], swats_monthly_temp_E_5, color = 'red', linewidth = 1, label = '5 cm')
axes[0,0].plot(swats_monthly_temp_E_15['time'], swats_monthly_temp_E_15, color = 'green', linewidth = 1, label = '15 cm')
axes[0,0].plot(swats_monthly_temp_E_25['time'], swats_monthly_temp_E_25, color = 'blue', linewidth = 1, label = '25 cm')
axes[0,0].plot(swats_monthly_temp_E_35['time'], swats_monthly_temp_E_35, color = 'purple', linewidth = 1, label = '35 cm')
axes[0,0].plot(swats_monthly_temp_E_60['time'], swats_monthly_temp_E_60, color = 'orange', linewidth = 1, label = '60 cm')
axes[0,0].set_ylabel('Temperature (C)', fontsize = 12)
#axes[0,0].xaxis.set_major_locator(mdates.MonthLocator())
#axes[0,0].xaxis.set_major_formatter(mdates.DateFormatter('%b'))
axes[0,0].tick_params(axis = 'x', labelrotation = 45, labelsize = 6)
axes[0,0].set_title("a) SWATS East Monthly Mean Soil Temperature (C)", fontweight = 'bold', fontsize = 12)
axes[0,0].legend(loc = "lower right", fontsize = 8)


###  STAMP ###
#5cm, 10, 20, 50, 75, 100

#5cm
stamp_tempE_5 = stamp['soil_temperature_east'].isel(depth=0)
stamp_monthly_tempE_5 = stamp_tempE_5.resample(time='1ME').mean()

#10cm
stamp_tempE_10 = stamp['soil_temperature_east'].isel(depth=1)
stamp_monthly_tempE_10 = stamp_tempE_10.resample(time='1ME').mean()

#20cm
stamp_tempE_20 = stamp['soil_temperature_east'].isel(depth=2)
stamp_monthly_tempE_20 = stamp_tempE_20.resample(time='1ME').mean()

#50cm 
stamp_tempE_50 = stamp['soil_temperature_east'].isel(depth=3)
stamp_monthly_tempE_50 = stamp_tempE_50.resample(time='1ME').mean()

#75cm
stamp_tempE_75 = stamp['soil_temperature_east'].isel(depth=4)
stamp_monthly_tempE_75 = stamp_tempE_75.resample(time='1ME').mean()

#100cm
stamp_tempE_100 = stamp['soil_temperature_east'].isel(depth=5)
stamp_monthly_tempE_100 = stamp_tempE_100.resample(time='1ME').mean()

#stamp temps plot b
axes[0,1].plot(stamp_monthly_tempE_5['time'], stamp_monthly_tempE_5, color = 'red', linewidth = 1, label = '5 cm')
axes[0,1].plot(stamp_monthly_tempE_10['time'], stamp_monthly_tempE_10, color = 'green', linewidth = 1, label = '10 cm')
axes[0,1].plot(stamp_monthly_tempE_20['time'], stamp_monthly_tempE_20, color = 'blue', linewidth = 1, label = '20 cm')
axes[0,1].plot(stamp_monthly_tempE_50['time'], stamp_monthly_tempE_50, color = 'purple', linewidth = 1, label = '50 cm')
axes[0,1].plot(stamp_monthly_tempE_75['time'], stamp_monthly_tempE_75, color = 'orange', linewidth = 1, label = '75 cm')
axes[0,1].plot(stamp_monthly_tempE_100['time'], stamp_monthly_tempE_100, color = 'black', linewidth = 1, label = '100 cm')
axes[0,1].set_ylabel('Temperature (C)', fontsize = 12)
#axes[0,1].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
axes[0,1].tick_params(axis = 'x', labelrotation = 45, labelsize = 6)
axes[0,1].set_title("b) STAMP East Monthly Mean Soil Temperature (C)", fontweight = 'bold', fontsize = 12)
axes[0,1].legend(loc = "lower right", fontsize = 8)


##### WEST #####
#5cm, STARTING WITH SWATS (plot C)
swats_tempW_5 = swats['tsoil_w'].isel(depth=0)
swats_monthly_temp_W_5 = swats_tempW_5.resample(time='1ME').mean()

#15cm
swats_tempW_15 = swats['tsoil_w'].isel(depth=1)
swats_monthly_temp_W_15 = swats_tempW_15.resample(time='1ME').mean()

#25cm
swats_tempW_25 = swats['tsoil_w'].isel(depth=2)
swats_monthly_temp_W_25 = swats_tempW_25.resample(time='1ME').mean()


#35cm
swats_tempW_35 = swats['tsoil_w'].isel(depth=3)
swats_monthly_temp_W_35 = swats_tempW_35.resample(time='1ME').mean()

#60cm
swats_tempW_60 = swats['tsoil_w'].isel(depth=4)
swats_monthly_temp_W_60 = swats_tempW_60.resample(time='1ME').mean()

#swats temps plot (c)
axes[1,0].plot(swats_monthly_temp_W_5['time'], swats_monthly_temp_W_5, color = 'red', linewidth = 1, label = '5 cm')
axes[1,0].plot(swats_monthly_temp_W_15['time'], swats_monthly_temp_W_15, color = 'green', linewidth = 1, label = '15 cm')
axes[1,0].plot(swats_monthly_temp_W_25['time'], swats_monthly_temp_W_25, color = 'blue', linewidth = 1, label = '25 cm')
axes[1,0].plot(swats_monthly_temp_W_35['time'], swats_monthly_temp_W_35, color = 'purple', linewidth = 1, label = '35 cm')
axes[1,0].plot(swats_monthly_temp_W_60['time'], swats_monthly_temp_W_60, color = 'orange', linewidth = 1, label = '60 cm')
axes[1,0].set_ylabel('Temperature (C)', fontsize = 12)
#axes[1,0].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
axes[1,0].tick_params(axis = 'x', labelrotation = 45, labelsize = 6)
axes[1,0].set_title("c) SWATS West Monthly Mean Soil Temperature (C)", fontweight = 'bold', fontsize = 12)
axes[1,0].legend(loc = "lower right", fontsize = 8)

###  STAMP ###
#5cm
stamp_tempW_5 = stamp['soil_temperature_west'].isel(depth=0)
stamp_monthly_tempW_5 = stamp_tempW_5.resample(time='1ME').mean()

#10cm
stamp_tempW_10 = stamp['soil_temperature_west'].isel(depth=1)
stamp_monthly_tempW_10 = stamp_tempW_10.resample(time='1ME').mean()

#20cm
stamp_tempW_20 = stamp['soil_temperature_west'].isel(depth=2)
stamp_monthly_tempW_20 = stamp_tempW_20.resample(time='1ME').mean()

#50cm 
stamp_tempW_50 = stamp['soil_temperature_west'].isel(depth=3)
stamp_monthly_tempW_50 = stamp_tempW_50.resample(time='1ME').mean()

#75cm
stamp_tempW_75 = stamp['soil_temperature_west'].isel(depth=4)
stamp_monthly_tempW_75 = stamp_tempW_75.resample(time='1ME').mean()

#100cm
stamp_tempW_100 = stamp['soil_temperature_west'].isel(depth=5)
stamp_monthly_tempW_100 = stamp_tempW_100.resample(time='1ME').mean()

#stamp temps plot d
axes[1,1].plot(stamp_monthly_tempW_5['time'], stamp_monthly_tempW_5, color = 'red', linewidth = 1, label = '5 cm')
axes[1,1].plot(stamp_monthly_tempW_10['time'], stamp_monthly_tempW_10, color = 'green', linewidth = 1, label = '10 cm')
axes[1,1].plot(stamp_monthly_tempW_20['time'], stamp_monthly_tempW_20, color = 'blue', linewidth = 1, label = '20 cm')
axes[1,1].plot(stamp_monthly_tempW_50['time'], stamp_monthly_tempW_50, color = 'purple', linewidth = 1, label = '50 cm')
axes[1,1].plot(stamp_monthly_tempW_75['time'], stamp_monthly_tempW_75, color = 'orange', linewidth = 1, label = '75 cm')
axes[1,1].plot(stamp_monthly_tempW_100['time'], stamp_monthly_tempW_100, color = 'black', linewidth = 1, label = '100 cm')
axes[1,1].set_ylabel('Temperature (C)', fontsize = 12)
#axes[1,1].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
axes[1,1].tick_params(axis = 'x', labelrotation = 45, labelsize = 6)
axes[1,1].set_title("d) STAMP West Monthly Mean Soil Temperature (C)", fontweight = 'bold', fontsize = 12)
axes[1,1].legend(loc = "lower right", fontsize = 8)

def month_or_year(x, pos=None):
    date = mdates.num2date(x)
    if date.month == 1:
        return date.strftime('%b\n%Y')   # Jan with year underneath
    else:
        return date.strftime('%b')       # Other months only

for ax in axes.flat:
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(month_or_year)
    ax.tick_params(axis='x', labelrotation=0, labelsize=9)

fig.suptitle(f"ARM STAMP & SWATS Temperature (C) Data Analysis from 2016/02/22 to 2017/07/03, \n Site E13, All Depths", fontweight = 'bold', fontsize = 20)           
plt.subplots_adjust(hspace=0.4, wspace = 0.2)
#plt.savefig('monthly_ARM_temp_analysis_all_depths.png', dpi=300, bbox_inches='tight')
